# %% [markdown]
# <a href="https://colab.research.google.com/github/inessellami/QM2-Project-/blob/Code/Data_Merging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
income = files.upload()
# Out:
#      <input type="file" id="files-6a704572-fd01-4cd2-a285-15f15e426b86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a704572-fd01-4cd2-a285-15f15e426b86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving median.csv to median.csv

# %%
from google.colab import files
education = files.upload()
# Out:
#      <input type="file" id="files-de0c34e2-756a-4358-927c-efe693e05c23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de0c34e2-756a-4358-927c-efe693e05c23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sample_data_Education.csv to sample_data_Education.csv

# %%
from google.colab import files
abortion = files.upload()
# Out:
#      <input type="file" id="files-f5e6bad6-11d2-40d1-8328-69ed6104310c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5e6bad6-11d2-40d1-8328-69ed6104310c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving abortion rate data.csv to abortion rate data.csv

# %%
from google.colab import files
religion = files.upload()
# Out:
#      <input type="file" id="files-f56d67f1-3c49-44d5-b5ea-190b333cdd75" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f56d67f1-3c49-44d5-b5ea-190b333cdd75">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sample_data_Religiosity.csv to sample_data_Religiosity.csv

# %%
from google.colab import files
politic = files.upload()
# Out:
#      <input type="file" id="files-9b5273b8-ccae-4017-ab36-194f46c1648b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b5273b8-ccae-4017-ab36-194f46c1648b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sample_data_Political Affiliation.csv to sample_data_Political Affiliation.csv

# %%
# 1. Data merge

income = pd.read_csv('median.csv')
education = pd.read_csv('sample_data_Education.csv')
abortion = pd.read_csv('abortion rate data.csv')
religion = pd.read_csv('sample_data_Religiosity.csv')
politic = pd.read_csv('sample_data_Political Affiliation.csv')

abortion.head()
# Out:
#        States  Abortion rate
# 0     Alabama             8.3
# 1      Alaska             9.9
# 2     Arizona            10.5
# 3    Arkansas             6.2
# 4  California            17.3

# %%
religion['State'] = religion['State'].astype(str)
income['State'] = income['State'].astype(str)
education['State'] = education['State'].astype(str)
abortion['States'] = abortion['States'].astype(str)
politic['State'] = politic['State'].astype(str)


religion.set_index('State')
income.set_index('State')
education.set_index('State')
abortion.set_index('States')
politic.set_index('State')
income.index.name = "code"
education.index.name = "code"
abortion.index.name = "code"
politic.index.name = "code"
religion.index.name = "code"

# %%
merged = income.merge(abortion, left_on = 'code', right_on = 'code') 
merged1 = merged.merge(education, left_on = 'code', right_on = 'code')
merged2 = merged1.merge(religion, left_on = 'code', right_on = 'code')
df = merged2.merge(politic, left_on = 'code', right_on = 'code')
#df.drop(columns=['U.S. State'], inplace= True)
df.drop(columns=['State_y'], inplace= True)
#df.drop(columns=['State'], inplace= True)
df.drop(columns=['States'], inplace= True)

df.rename(columns={'High':'religion'}, inplace=True) 
df.rename(columns={'2014-2018':'education'}, inplace=True)
abortion.rename(columns={'Abortion rate ':'abortion'}, inplace=True)
df.rename(columns={'Median income in 2014':'income'}, inplace=True)
df.rename(columns={'Republican/lean Rep. (percentage)':'Rep'}, inplace=True)
df.rename(columns={'Democrat/ lean. Dem. (percentage)':'Dem'}, inplace=True)
df.rename(columns={'Abortion rate':'abortion'}, inplace=True) 
df.rename(columns={'State_x':'state'}, inplace=True) 


# Remove the "," in income values and convert to numeric type
df['income'] = df['income'].str.replace(',', '')
df['income'] = pd.to_numeric(df['income'])

df
# Out:
#                      state  income  abortion  ...  religion Rep  Dem
# code                                          ...
# 0                  Alabama   42278       8.3  ...        77  52   35
# 1                   Alaska   67629       9.9  ...        45  39   32
# 2                  Arizona   49254      10.5  ...        53  40   39
# 3                 Arkansas   44922       6.2  ...        70  46   38
# 4               California   60487      17.3  ...        49  30   49
# 5                 Colorado   60940       9.8  ...        47  41   42
# 6              Connecticut   70161      18.2  ...        43  32   50
# 7                 Delaware   57522      16.1  ...        52  29   55
# 8     District of Columbia   68277      15.5  ...        53  11   73
# 9                  Florida   46140      17.5  ...        54  37   44
# 10                 Georgia   49555      15.2  ...        66  41   41
# 11                  Hawaii   71223      11.7  ...        47  28   51
# 12                   Idaho   53438       5.5  ...        51  49   32
# 13                Illinois   54916      14.7  ...        51  33   48
# 14                 Indiana   48060       7.9  ...        54  42   37
# 15                    Iowa   57810       6.9  ...        55  41   40
# 16                  Kansas   53444       6.3  ...        55  46   31
# 17                Kentucky   42786       5.5  ...        63  44   43
# 18               Louisiana   42406      10.7  ...        71  41   43
# 19                   Maine   51710       9.0  ...        34  36   47
# 20                Maryland   76165      21.7  ...        54  31   55
# 21           Massachusetts   63151      14.1  ...        33  27   56
# 22                Michigan   52005      14.1  ...        53  34   47
# 23               Minnesota   67244       9.1  ...        49  39   46
# 24             Mississippi   35521       8.6  ...        77  44   42
# 25                Missouri   56630       8.6  ...        60  41   42
# 26                 Montana   51102       8.2  ...        48  49   30
# 27                Nebraska   56870       5.9  ...        54  47   36
# 28                  Nevada   49875      16.5  ...        49  37   46
# 29           New Hampshire   73397       9.9  ...        33  35   44
# 30              New Jersey   65243      28.2  ...        55  30   51
# 31              New Mexico   46686      10.6  ...        57  37   48
# 32                New York   54310      27.4  ...        46  28   53
# 33          North Carolina   46784      11.6  ...        65  41   43
# 34            North Dakota   60730       6.6  ...        53  50   33
# 35                    Ohio   49644       9.4  ...        58  42   40
# 36                Oklahoma   47199       5.9  ...        66  45   40
# 37                  Oregon   58875      11.4  ...        48  32   47
# 38            Pennsylvania   55173      14.6  ...        53  39   46
# 39            Rhode Island   58633      16.0  ...        49  30   48
# 40          South Carolina   44929      11.4  ...        70  43   39
# 41            South Dakota   53053       4.6  ...        59  53   37
# 42               Tennessee   43716       8.6  ...        73  48   36
# 43                   Texas   53875       9.4  ...        64  39   40
# 44                    Utah   63383       4.6  ...        64  54   30
# 45                 Vermont   60708      11.1  ...        34  29   57
# 46                Virginia   66155      13.1  ...        61  43   39
# 47              Washington   59068      12.1  ...        45  33   44
# 48           West Virginia   39552       7.6  ...        69  43   41
# 49               Wisconsin   58080       6.8  ...        45  42   42
# 50                 Wyoming   55690       7.0  ...        54  57   25
#
# [51 rows x 8 columns]

# %%
df.to_csv(r'sample_data\Final marged dataset.csv', index = False)
