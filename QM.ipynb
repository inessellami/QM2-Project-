# %% [markdown]
# <a href="https://colab.research.google.com/github/inessellami/QM2-Project-/blob/main/QM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-19e79598-3241-487e-abff-cd6447ae0f4e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-19e79598-3241-487e-abff-cd6447ae0f4e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BASC.csv to BASC (1).csv

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm

# %%
df =  pd.read_csv('BASC.csv', index_col = 0)
df.drop(['Republican','Democrat','Neutral'], inplace = True, axis = 1)

# %%
df.head()

# %%
lm = linear_model.LinearRegression()
lm.fit(df[['Income','Education','Religion']],df.Abortion)
lm.coef_
# Out:
# array([ 4.66044897e-04,  1.37422147e+02, -1.67699995e-01])

# %%
df_dummy = pd.get_dummies(df['Party'])
df_dummy = pd.concat([df,df_dummy],axis = 1)
df_dummy.drop(['Party','Democrat'], axis = 1, inplace = True)
df_dummy
# Out:
#               States  Income  Income2  ...  GEO  Neutral  Republican
# Rank                                   ...
# 1            Alabama   42830    23606  ...    1        0           1
# 2             Alaska   71583    33062  ...    2        0           1
# 3            Arizona   50068    25715  ...    4        0           1
# 4           Arkansas   41262    22883  ...    5        0           1
# 5         California   61933    30441  ...    6        0           0
# 6           Colorado   61303    32357  ...    8        0           0
# 7        Connecticut   70048    39373  ...    9        0           0
# 8           Delaware   59716    30488  ...   10        0           0
# 9                 DC   71648    45877  ...   11        0           0
# 10           Florida   47463    26582  ...   12        0           0
# 11           Georgia   49321    25615  ...   13        1           0
# 12            Hawaii   69592    29736  ...   15        0           0
# ...

# %%
model = sm.OLS.from_formula('Abortion ~ Income + Education + Religion', df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Abortion   R-squared:                       0.488
# Model:                            OLS   Adj. R-squared:                  0.455
# Method:                 Least Squares   F-statistic:                     14.91
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):           5.94e-07
# Time:                        12:07:44   Log-Likelihood:                -151.47
# No. Observations:                  51   AIC:                             310.9
# Df Residuals:                      47   BIC:                             318.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -19.0212      8.651     -2.199      0.033     -36.424      -1.618
# ...

# %%
model_2 = sm.OLS(df_dummy['Abortion'], sm.add_constant(df_dummy[['Income','Education','Religion','Republican']])).fit()

model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Abortion   R-squared:                       0.703
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                     21.34
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):           7.04e-11
# Time:                        12:05:11   Log-Likelihood:                -137.53
# No. Observations:                  51   AIC:                             287.1
# Df Residuals:                      45   BIC:                             298.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.5054      9.083      1.047      0.301      -8.788      27.799
# ...
